# %%
import os

# %%
os.chdir('/content/drive/MyDrive/cow_detection_new')

# %%
import cv2

# %%
path = './images'
for folder in sorted(os.listdir(path)):
    for image in sorted(os.listdir(os.path.join(path,folder))):
        img_path = os.path.join(path,folder)
        img = cv2.imread(img_path+'/'+image)
        print(img_path+'/'+image)
        n_img = cv2.resize(img, None, fx=0.15, fy=0.15, interpolation=cv2.INTER_AREA)
        cv2.imwrite(img_path+'/'+image, n_img)
        #cv2.imwrite('./test.jpg', n_img)

# %% [markdown]
# ## Resize input image

# %% [markdown]
# # Training network

# %%
# !pip install -r requirements.txt

# %%
# !pip install wandb

# %%
# !python train.py --cfg models/yolov5s.yaml --hyp data/hyp.scratch.yaml --batch 16 --epochs 100 --data data/cow_data.yml --weights weights/yolov5s.pt --workers 24 --name cow_det --device 0 --rect --img 600
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 2021-6-4 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='models/yolov5s.yaml', data='data/cow_data.yml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[600, 600], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='cow_det', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=True, resume=False, save_dir='runs/train/cow_det7', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='weights/yolov5s.pt', workers=24, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --source ./images/test/ --weights runs/train/cow_det7/weights/best.pt --conf 0.2 --name cow_det --img-size 600
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=600, iou_thres=0.45, line_thickness=3, max_det=1000, name='cow_det', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='./images/test/', update=False, view_img=False, weights=['runs/train/cow_det7/weights/best.pt'])
# YOLOv5 🚀 2021-6-4 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# WARNING: --img-size 600 must be multiple of max stride 32, updating to 608
# image 1/14 /content/drive/My Drive/cow_detection_new/images/test/DJI_0026.JPG: 480x608 11 animals, Done. (0.011s)
# image 2/14 /content/drive/My Drive/cow_detection_new/images/test/DJI_0027.JPG: 480x608 8 animals, Done. (0.010s)
# image 3/14 /content/drive/My Drive/cow_detection_new/images/test/DJI_0028.JPG: 480x608 9 animals, Done. (0.010s)
# ...

# %%
os.chdir('/content/drive/MyDrive/cow_detection_new')

# %%
from time import sleep
import matplotlib.pyplot as plt

# %%
import cv2

# %%
w,h = 450,600
path = './runs/detect/cow_det2'
#fourcc = cv2.VideoWriter_fourcc('M', 'J', 'P', 'G')
fps = 2
vid_writer = cv2.VideoWriter('./cow2.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (h, w))
for img in sorted(os.listdir(path)):
    cap = cv2.VideoCapture(path+'/'+img)
    ret, frame = cap.read()
    if ret:
        sleep(3)
        print(f"read image --> {(path+'/'+img)}")
        vid_writer.write(frame)
vid_writer.release()
# Out:
# read image --> ./runs/detect/cow_det2/DJI_0026.JPG
# read image --> ./runs/detect/cow_det2/DJI_0027.JPG
# read image --> ./runs/detect/cow_det2/DJI_0028.JPG
# read image --> ./runs/detect/cow_det2/DJI_0029.JPG
# read image --> ./runs/detect/cow_det2/DJI_0030.JPG
# read image --> ./runs/detect/cow_det2/DJI_0031.JPG
# read image --> ./runs/detect/cow_det2/DJI_0032.JPG
# read image --> ./runs/detect/cow_det2/DJI_0033.JPG
# read image --> ./runs/detect/cow_det2/DJI_0034.JPG
# read image --> ./runs/detect/cow_det2/DJI_0035.JPG
# read image --> ./runs/detect/cow_det2/DJI_0036.JPG
# read image --> ./runs/detect/cow_det2/DJI_0037.JPG
# read image --> ./runs/detect/cow_det2/DJI_0038.JPG
# read image --> ./runs/detect/cow_det2/DJI_0039.JPG
